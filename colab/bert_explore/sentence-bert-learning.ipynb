# %% [markdown]
# #BERT development praparation
# BERT needs python3.6, tensorflow1.13.1, pytorch1.10.0, pytorch-transformers1.2.0 to run properly.

# %%
# !python -V
# !pip install sentence-transformers
# !python -V
# Out:
# Python 3.10.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 71.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.3 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=d4462bbc4b561827ad8286bcd9f7edb42ee4fd71926cf830cdb90f36da90b7bf
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...
# Python 3.10.11

# %% [markdown]
# Install Cuda10.0 and CuDNN7.4 to cope with Tensorflow1.13.1.

# %%
# %cd /content/drive/MyDrive/libs
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

#!wget  --no-clobber https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-repo-ubuntu1804_10.0.130-1_amd64.deb
#install CUDA kit dpkg
# !dpkg -i cuda-repo-ubuntu1804_10.0.130-1_amd64.deb
# !sudo apt-key adv --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-10-0
#%cd /content/drive/MyDrive/Code
#!wget https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64/libcudnn7-dev_7.4.2.24-1+cuda10.0_amd64.deb
#!wget https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64/libcudnn7_7.4.2.24-1+cuda10.0_amd64.deb
# !dpkg -i libcudnn7_7.4.2.24-1+cuda10.0_amd64.deb
# !dpkg -i libcudnn7-dev_7.4.2.24-1+cuda10.0_amd64.deb

# %% [markdown]
# 0.GLUE data

# %%
# %cd /content/drive/MyDrive/Code
# %pwd
# for i in ["CoLA", "SST", "MRPC", "QQP", "STS", "MNLI", "QNLI", "RTE", "WNLI", "diagnostic"]:
#   !python download_glue.py --data_dir data --tasks $i

# %% [markdown]
# #STS-BERT-Small

# %%
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT="stsb_L-6_H-768_A-12"
#!wget https://transformers-models.obs.cn-north-4.myhuaweicloud.com/bert/cn/pretrain/pt/stsb_L-6_H-768_A-12.zip -P /content/drive/MyDrive/Code_analysis
# !unzip stsb_L-6_H-768_A-12.zip
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT="stsb_L-6_H-768_A-12"
# Archive:  stsb_L-6_H-768_A-12.zip
#    creating: stsb_L-6_H-768_A-12/
#   inflating: __MACOSX/._stsb_L-6_H-768_A-12
#   inflating: stsb_L-6_H-768_A-12/.DS_Store
#   inflating: __MACOSX/stsb_L-6_H-768_A-12/._.DS_Store
#    creating: stsb_L-6_H-768_A-12/0_Transformer/
#    creating: stsb_L-6_H-768_A-12/1_Pooling/
#   inflating: stsb_L-6_H-768_A-12/config.json
#   inflating: stsb_L-6_H-768_A-12/similarity_evaluation_sts-dev_results.csv
#   inflating: __MACOSX/stsb_L-6_H-768_A-12/._similarity_evaluation_sts-dev_results.csv
#   inflating: stsb_L-6_H-768_A-12/similarity_evaluation_sts-test_results.csv
#   inflating: __MACOSX/stsb_L-6_H-768_A-12/._similarity_evaluation_sts-test_results.csv
#   inflating: stsb_L-6_H-768_A-12/modules.json
#   inflating: stsb_L-6_H-768_A-12/0_Transformer/tokenizer_config.json
#   inflating: stsb_L-6_H-768_A-12/0_Transformer/special_tokens_map.json
# ...

# %%
#!rm -rf /content/drive/MyDrive/Code_analysis/__MACOSX
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT='stsb_L-6_H-768_A-12'
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('stsb_L-6_H-768_A-12')
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT='stsb_L-6_H-768_A-12'
# [[-0.7314539  -0.08819485 -0.615063   ...  0.03086787 -0.28416815
#    0.08606638]
#  [-0.62926745 -0.10480428  0.54403764 ... -0.01268858 -0.23684973
#    0.23438622]]

# %% [markdown]
# #STS-BERT-Base

# %%
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT='stsb_L-12_H-768_A-12'
# !wget https://transformers-models.obs.cn-north-4.myhuaweicloud.com/bert/cn/pretrain/pt/stsb_L-12_H-768_A-12.zip -P /content/drive/MyDrive/Code_analysis
# !unzip stsb_L-12_H-768_A-12.zip
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT='stsb_L-12_H-768_A-12'
# --2023-05-27 14:12:48--  https://transformers-models.obs.cn-north-4.myhuaweicloud.com/bert/cn/pretrain/pt/stsb_L-12_H-768_A-12.zip
# Resolving transformers-models.obs.cn-north-4.myhuaweicloud.com (transformers-models.obs.cn-north-4.myhuaweicloud.com)... 121.36.121.226, 121.36.121.227
# Connecting to transformers-models.obs.cn-north-4.myhuaweicloud.com (transformers-models.obs.cn-north-4.myhuaweicloud.com)|121.36.121.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460517276 (439M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Code_analysis/stsb_L-12_H-768_A-12.zip’
#
# stsb_L-12_H-768_A-1 100%[===================>] 439.18M  11.2MB/s    in 43s
#
# 2023-05-27 14:13:34 (10.2 MB/s) - ‘/content/drive/MyDrive/Code_analysis/stsb_L-12_H-768_A-12.zip’ saved [460517276/460517276]
#
# Archive:  stsb_L-12_H-768_A-12.zip
#    creating: stsb_L-12_H-768_A-12/
# ...

# %%
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT='stsb_L-12_H-768_A-12'
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer("stsb_L-12_H-768_A-12")
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT='stsb_L-12_H-768_A-12'
# [[-0.7046391   0.21647103  0.23562162 ... -0.8150509  -0.3474671
#    0.6278895 ]
#  [ 0.05422468  0.8920975   0.14136209 ...  0.6420072   0.23305048
#    0.75140715]]

# %% [markdown]
# #STS-BERT-Large

# %%
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT='stsb_L-24_H-1024_A-16'
# !wget https://transformers-models.obs.cn-north-4.myhuaweicloud.com/bert/cn/pretrain/pt/stsb_L-24_H-1024_A-16.zip -P /content/drive/MyDrive/Code_analysis
# !unzip stsb_L-24_H-1024_A-16.zip
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT='stsb_L-24_H-1024_A-16'
# --2023-05-27 14:16:41--  https://transformers-models.obs.cn-north-4.myhuaweicloud.com/bert/cn/pretrain/pt/stsb_L-24_H-1024_A-16.zip
# Resolving transformers-models.obs.cn-north-4.myhuaweicloud.com (transformers-models.obs.cn-north-4.myhuaweicloud.com)... 121.36.121.226, 121.36.121.227
# Connecting to transformers-models.obs.cn-north-4.myhuaweicloud.com (transformers-models.obs.cn-north-4.myhuaweicloud.com)|121.36.121.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1315465300 (1.2G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Code_analysis/stsb_L-24_H-1024_A-16.zip’
#
# stsb_L-24_H-1024_A- 100%[===================>]   1.22G  9.43MB/s    in 2m 2s
#
# 2023-05-27 14:18:46 (10.3 MB/s) - ‘/content/drive/MyDrive/Code_analysis/stsb_L-24_H-1024_A-16.zip’ saved [1315465300/1315465300]
#
# Archive:  stsb_L-24_H-1024_A-16.zip
#    creating: stsb_L-24_H-1024_A-16/
# ...

# %%
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT='stsb_L-24_H-1024_A-16'
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('stsb_L-24_H-1024_A-16')
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT='stsb_L-24_H-1024_A-16'
# [[ 1.2174264  -1.4104813   0.35468286 ...  0.12470629 -1.5021343
#    0.7092635 ]
#  [ 0.24340534  0.1856866   0.7899885  ... -0.06824937 -0.7366762
#   -0.13839279]]

# %% [markdown]
# #STS-BERT-Base-Multi-Language

# %%
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT='stsb-multi_L-12_H-768_A-12'
# !wget https://transformers-models.obs.cn-north-4.myhuaweicloud.com/bert/cn/pretrain/pt/stsb-multi_L-12_H-768_A-12.zip -P /content/drive/MyDrive/Code_analysis
# !unzip stsb-multi_L-12_H-768_A-12.zip
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT='stsb-multi_L-12_H-768_A-12'
# --2023-05-27 14:20:29--  https://transformers-models.obs.cn-north-4.myhuaweicloud.com/bert/cn/pretrain/pt/stsb-multi_L-12_H-768_A-12.zip
# Resolving transformers-models.obs.cn-north-4.myhuaweicloud.com (transformers-models.obs.cn-north-4.myhuaweicloud.com)... 121.36.121.226, 121.36.121.227
# Connecting to transformers-models.obs.cn-north-4.myhuaweicloud.com (transformers-models.obs.cn-north-4.myhuaweicloud.com)|121.36.121.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1013943541 (967M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Code_analysis/stsb-multi_L-12_H-768_A-12.zip’
#
# stsb-multi_L-12_H-7 100%[===================>] 966.97M  9.24MB/s    in 96s
#
# 2023-05-27 14:22:07 (10.1 MB/s) - ‘/content/drive/MyDrive/Code_analysis/stsb-multi_L-12_H-768_A-12.zip’ saved [1013943541/1013943541]
#
# Archive:  stsb-multi_L-12_H-768_A-12.zip
# ...

# %%
# %cd /content/drive/MyDrive/Code_analysis
# %env STS_BERT='stsb-multi_L-12_H-768_A-12'
from sentence_transformers import SentenceTransformer
sentences = ["你好，ChatGPT", "Each sentence is converted"]

model = SentenceTransformer("stsb-multi_L-12_H-768_A-12")
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# /content/drive/MyDrive/Code_analysis
# env: STS_BERT='stsb-multi_L-12_H-768_A-12'
# [[-0.69148445  0.21631484  0.8012768  ...  0.27085465 -0.15033923
#    0.78368795]
#  [ 0.44954604  0.3481439   1.2075764  ...  0.16226219  0.31875917
#    0.18042566]]

# %%
# %cd /content/drive/MyDrive/Code_analysis
# !zip  -r  stsb-multi_L-12_H-768_A-12.zip stsb-multi_L-12_H-768_A-12/
# !zip  -r  stsb_L-12_H-768_A-12.zip stsb_L-12_H-768_A-12/
# !zip  -r  stsb_L-24_H-1024_A-16.zip stsb_L-24_H-1024_A-16/
# !zip  -r  stsb_L-6_H-768_A-12.zip stsb_L-6_H-768_A-12/
# !obsutil cp stsb-multi_L-12_H-768_A-12.zip obs://transformers-models/bert/cn/pretrain/pt/
# !obsutil cp stsb_L-12_H-768_A-12.zip obs://transformers-models/bert/cn/pretrain/pt/
# !obsutil cp stsb_L-24_H-1024_A-16.zip obs://transformers-models/bert/cn/pretrain/pt/
# !obsutil cp stsb_L-6_H-768_A-12.zip obs://transformers-models/bert/cn/pretrain/pt/
# Out:
# /content/drive/MyDrive/Code_analysis
# Start at 2023-05-27 14:48:42.334527576 +0000 UTC
#
#
# Parallel:      5                   Jobs:          5
# Threshold:     50.00MB             PartSize:      auto
# VerifyLength:  false               VerifyMd5:     false
# CheckpointDir: /root/.obsutil_checkpoint
#
#
# Waiting for the uploaded key to be completed on server side.
#
#
# Upload successfully, 966.88MB, n/a, /content/drive/MyDrive/Code_analysis/stsb-multi_L-12_H-768_A-12.zip --> obs://transformers-models/bert/cn/pretrain/pt/stsb-multi_L-12_H-768_A-12.zip, cost [6060], status [200], request id [000001885DAF056BD3CB410915070AE5]

# %% [markdown]
# #Obsutil

# %%
# %cd /content/drive/MyDrive/Code
# !wget https://obs-community-intl.obs.ap-southeast-1.myhuaweicloud.com/obsutil/current/obsutil_linux_amd64.tar.gz -P /content/drive/MyDrive/Code
# !tar xvf obsutil_linux_amd64.tar.gz
# !chmod 777 obsutil_linux_amd64_5.4.11/obsutil
# !mv obsutil_linux_amd64_5.4.11/obsutil /bin/
# !rm -rf /content/drive/MyDrive/Code/obsutil_linux_amd64_5.4.11
# Out:
# /content/drive/MyDrive/Code
# --2023-05-27 14:22:39--  https://obs-community-intl.obs.ap-southeast-1.myhuaweicloud.com/obsutil/current/obsutil_linux_amd64.tar.gz
# Resolving obs-community-intl.obs.ap-southeast-1.myhuaweicloud.com (obs-community-intl.obs.ap-southeast-1.myhuaweicloud.com)... 27.126.206.60
# Connecting to obs-community-intl.obs.ap-southeast-1.myhuaweicloud.com (obs-community-intl.obs.ap-southeast-1.myhuaweicloud.com)|27.126.206.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3646148 (3.5M) [application/gzip]
# Saving to: ‘/content/drive/MyDrive/Code/obsutil_linux_amd64.tar.gz’
#
# obsutil_linux_amd64 100%[===================>]   3.48M  1.90MB/s    in 1.8s
#
# 2023-05-27 14:22:43 (1.90 MB/s) - ‘/content/drive/MyDrive/Code/obsutil_linux_amd64.tar.gz’ saved [3646148/3646148]
#
# obsutil_linux_amd64_5.4.11/
# obsutil_linux_amd64_5.4.11/setup.sh
# obsutil_linux_amd64_5.4.11/obsutil
